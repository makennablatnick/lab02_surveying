# %% [markdown]
# ### Lab 02 Surveying Set Up Log - Green Team

# %% [markdown]
# ##### Grid Setup
#
# 	The grid was set up using a triangle method to ensure that it was perfectly square. We placed a stake at the Northernmost point, walked the tape measure out 20 meters and then walked another tape measure 28.82 (calculated using Pythagorean’s theorem) meters out to make the square.
#
#
# ##### Handheld GPS
#
# 	Data was collected with the Garmin oriented North and placed flat on the ground at each location of the flags
#
# ##### Total Station
#
#
# ##### Trimble R10 EMLID
#
# ##### mystery *Not Completed*
